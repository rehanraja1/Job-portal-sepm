# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
navoneel_brain_mri_images_for_brain_tumor_detection_path = kagglehub.dataset_download('navoneel/brain-mri-images-for-brain-tumor-detection')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
# Autor:        Asier Ortiz García
# Kaggle:       https://www.kaggle.com/code/asierortiz/brain-mri-tumor-detection-model-benchmark
# GitHub:       https://github.com/asier-ortiz/ai-course-notebooks/blob/main/actividad6_asier_ortiz.ipynb
# nbviewer:     https://nbviewer.org/github/asier-ortiz/ai-course-notebooks/blob/main/actividad6_asier_ortiz.ipynb

# %% [markdown]
# # Brain MRI Tumor Detection - Model Benchmark
#
# En el siguiente ejercicio se aplican técnicas de *Deep Learning* y *Transfer Learning* para detectar tumores cerebrales en imágenes MRI. Se comparan los modelos **VGG16**, **ResNet50** y **MobileNetV2**, utilizando **data augmentation** y un preprocesamiento basado en el **recorte de la región cerebral** de las imágenes.

# %% [markdown]
# ## 1 - Instalación de dependencias

# %%
from IPython.display import clear_output
# !pip install imutils
clear_output()

# %% [markdown]
# ## 2 - Importaciones y configuración

# %%
import itertools
import os
import shutil
import warnings

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_curve,
    auc
)

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input as mobilenet_preprocess
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input as resnet_preprocess
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input as vgg_preprocess
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img

import imutils

# %%
warnings.filterwarnings("ignore", category=UserWarning, module='keras.src.trainers.data_adapters.py_dataset_adapter')

# %%
# Ref. https://www.kaggle.com/docs/tpu
# Ref. https://www.kaggle.com/code/ryanholbrook/tpu-example
# Ref. https://www.kaggle.com/code/ryanholbrook/getting-started-with-tpus

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
    print("TPU disponible")
except ValueError:
    strategy = tf.distribute.get_strategy()
    print("TPU no disponible, usando CPU/GPU")

print("Número de réplicas:", strategy.num_replicas_in_sync)
# Out:
# TPU no disponible, usando CPU/GPU
# Número de réplicas: 1

# %%
# Constantes
RANDOM_SEED = 123
IMG_SIZE = (224, 224)
EPOCHS = 100
BATCH_SIZE = 32
VAL_BATCH_SIZE = 16

# Variables globales auxiliares
model_accuracies = []

# Callbacks
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

# %% [markdown]
# ## 3 - Preparación de datos

# %% [markdown]
# ### 3.1 Estructura de carpetas

# %%
# Limpieza del entorno por si ya existen carpetas de ejecuciones anteriores
# !rm -rf TRAIN TEST VAL TRAIN_CROP TEST_CROP VAL_CROP

# %%
# !mkdir -p TRAIN/YES TRAIN/NO TEST/YES TEST/NO VAL/YES VAL/NO
# !apt-get install tree > /dev/null
clear_output()
# !tree -d
# Out:
# .
# ├── sample_data
# ├── TEST
# │   ├── NO
# │   └── YES
# ├── TRAIN
# │   ├── NO
# │   └── YES
# └── VAL
#     ├── NO
#     └── YES
#
# 10 directories

# %% [markdown]
# ### 3.2 - División del dataset original en TRAIN / VAL / TEST

# %%
IMG_PATH = '/kaggle/input/brain-mri-images-for-brain-tumor-detection/'

for CLASS in os.listdir(IMG_PATH):
    if (os.path.isfile(CLASS) == False) and (CLASS == "yes" or CLASS == "no"):
        IMG_NUM = len(os.listdir(IMG_PATH + CLASS))
        for n, FILE_NAME in enumerate(os.listdir(IMG_PATH + CLASS)):
            img = IMG_PATH + CLASS + '/' + FILE_NAME
            if n < 5:
                shutil.copy(img, 'TEST/' + CLASS.upper() + '/' + FILE_NAME)
            elif n < 0.8 * IMG_NUM:
                shutil.copy(img, 'TRAIN/' + CLASS.upper() + '/' + FILE_NAME)
            else:
                shutil.copy(img, 'VAL/' + CLASS.upper() + '/' + FILE_NAME)

# %% [markdown]
# ### 3.3 - Función auxiliar para la carga datos

# %%
def load_data(dir_path):
    X = []
    y = []
    i = 0
    labels = dict()

    for path in sorted(os.listdir(dir_path)):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(dir_path + path):
                if not file.startswith('.'):
                    img = cv2.imread(dir_path + path + '/' + file)
                    X.append(img)
                    y.append(i)
            i += 1

    return np.array(X, dtype=object), np.array(y), labels

# %% [markdown]
# ### 3.4 - Función auxiliar para la visualización de muestras

# %%
def plot_samples(X, y, labels_dict, n=50):
    """
    Muestra una galería de 'n' imágenes del conjunto indicado
    """
    for index in range(len(labels_dict)):
        imgs = X[np.argwhere(y == index)][:n]
        j = 10
        i = int(n/j)

        plt.figure(figsize=(15,6))
        c = 1
        for img in imgs:
            plt.subplot(i,j,c)
            plt.imshow(img[0])

            plt.xticks([])
            plt.yticks([])
            c += 1
        plt.suptitle('Tumor: {}'.format(labels_dict[index]))
        plt.show()

# %% [markdown]
# ### 3.5 - Carga de imágenes y visualización de muestras

# %%
X_train, y_train, labels = load_data("TRAIN/")
X_val, y_val, _ = load_data("VAL/")
X_test, y_test, _ = load_data("TEST/")

plot_samples(X_train, y_train, labels, 30)

# %% [markdown]
# ## 4 - Preprocesamiento de imágenes

# %% [markdown]
# ### 4.1 - Función auxiliar para aplicar el recorte de la región cerebral

# %%
def crop_imgs(set_name, add_pixels_value=0):
    """
    Recorta la región cerebral de cada imagen en un conjunto
    """
    set_new = []

    for img in set_name:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])
        new_img = img[extTop[1]:extBot[1], extLeft[0]:extRight[0]].copy()
        set_new.append(new_img)

    return np.array(set_new, dtype=object)

# %% [markdown]
# ### 4.2 - Aplicar recorte y visualizar las muestras

# %%
X_train_crop = crop_imgs(X_train)
X_val_crop = crop_imgs(X_val)
X_test_crop = crop_imgs(X_test)

def plot_samples_class(X, y, labels, target_class, num_samples=15):
    """
    Visualiza una muestra de imágenes pertenecientes a una clase (con o sin tumor)
    """
    plt.figure(figsize=(15, 3))
    count = 0
    for i in range(len(X)):
        if y[i] == target_class:
            plt.subplot(1, num_samples, count + 1)
            plt.imshow(cv2.cvtColor(X[i], cv2.COLOR_BGR2RGB))
            plt.axis('off')
            count += 1
            if count == num_samples:
                break
    plt.suptitle(f"Tumor: {labels[target_class]}")
    plt.tight_layout()
    plt.show()

# %%
# Visualización antes del recorte
plot_samples_class(X_train, y_train, labels, 0)  # Clase NO
plot_samples_class(X_train, y_train, labels, 1)  # Clase YES

# %%
# Visualización después del recorte
plot_samples_class(X_train_crop, y_train, labels, 0)
plot_samples_class(X_train_crop, y_train, labels, 1)

# %% [markdown]
# ### 4.3 - Alamcenamiento de las imágenes recortadas

# %%
def save_new_images(x_set, y_set, folder_name):
    """
    Guarda las imágenes en carpetas separadas según su clase (NO o YES)
    """
    i = 0
    for (img, imclass) in zip(x_set, y_set):
        path = folder_name + ('NO/' if imclass == 0 else 'YES/')
        cv2.imwrite(path + str(i) + '.jpg', img)
        i += 1

# %%
# !mkdir TRAIN_CROP TEST_CROP VAL_CROP TRAIN_CROP/YES TRAIN_CROP/NO TEST_CROP/YES TEST_CROP/NO VAL_CROP/YES VAL_CROP/NO

# %%
save_new_images(X_train_crop, y_train, folder_name='TRAIN_CROP/')
save_new_images(X_val_crop, y_val, folder_name='VAL_CROP/')
save_new_images(X_test_crop, y_test, folder_name='TEST_CROP/')

# %% [markdown]
# ### 4.4 - Ejemplo de visualización con data augmentation

# %%
demo_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
    brightness_range=[0.1, 1.5],
    horizontal_flip=True,
    vertical_flip=True
)

x = X_train_crop[0]
x = x.reshape((1,) + x.shape)

# Imagen original
plt.imshow(cv2.cvtColor(X_train_crop[0], cv2.COLOR_BGR2RGB))
plt.title("Imagen original")
plt.axis("off")
plt.show()

# Imágenes aumentadas
plt.figure(figsize=(15, 6))
i = 0

for batch in demo_datagen.flow(x, batch_size=1):
    img = array_to_img(batch[0])
    plt.subplot(3, 7, i+1)
    plt.imshow(img)
    plt.axis('off')
    i += 1
    if i >= 21:
        break

plt.suptitle("Vista previa de imágenes aumentadas", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5 - Entrenamiento de modelos

# %% [markdown]
# ### 5.1 - Funciones auxiliares para entrenamiento y evaluación de modelos

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Matriz de Confusión', cmap=plt.cm.Blues):
    """
    Muestra la matriz de confusión como imagen, opcionalmente normalizada
    """
    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    thresh = cm.max() / 2.
    cm = np.round(cm, 2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('Etiqueta real')
    plt.xlabel('Etiqueta predicha')
    plt.show()

# %%
def plot_training_history(history, name):
    """
    Muestra la evolución de la precisión y la pérdida durante el entrenamiento y la validación
    """
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(history.epoch) + 1)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Entrenamiento')
    plt.plot(epochs_range, val_acc, label='Validación')
    plt.legend(loc="best")
    plt.xlabel('Épocas')
    plt.ylabel('Precisión')
    plt.title(f'{name} - Precisión')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Entrenamiento')
    plt.plot(epochs_range, val_loss, label='Validación')
    plt.legend(loc="best")
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.title(f'{name} - Pérdida')

    plt.tight_layout()
    plt.show()

# %%
def create_generators(preprocess_func):
    """
    Crea y devuelve los generadores de imágenes para entrenamiento y validación,
    aplicando aumentación de datos y el preprocesamiento correspondiente
    """

    train_datagen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.1,
        brightness_range=[0.5, 1.5],
        horizontal_flip=True,
        vertical_flip=True,
        preprocessing_function=preprocess_func
    )

    val_datagen = ImageDataGenerator(preprocessing_function=preprocess_func)

    train_generator = train_datagen.flow_from_directory(
        'TRAIN_CROP/', color_mode='rgb', target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='binary', seed=RANDOM_SEED
    )

    validation_generator = val_datagen.flow_from_directory(
        'VAL_CROP/', color_mode='rgb', target_size=IMG_SIZE, batch_size=VAL_BATCH_SIZE, class_mode='binary', seed=RANDOM_SEED
    )

    return train_generator, validation_generator

# %%
def evaluate_model(model, preprocess_func, name):
    """
    Evalúa el modelo sobre los conjuntos de validación y test.
    Imprime métricas de rendimiento, muestra ambas matrices de confusión,
    classification report y la curva ROC con el AUC
    """
    # Preprocesar validación y test
    X_val_prep = np.array([preprocess_func(cv2.resize(img, IMG_SIZE)) for img in X_val_crop])
    X_test_prep = np.array([preprocess_func(cv2.resize(img, IMG_SIZE)) for img in X_test_crop])

    # Predicciones
    y_val_probs = model.predict(X_val_prep).flatten()
    y_val_preds = (y_val_probs > 0.5).astype(int)

    y_test_probs = model.predict(X_test_prep).flatten()
    y_test_preds = (y_test_probs > 0.5).astype(int)

    # Accuracy
    val_acc = accuracy_score(y_val, y_val_preds)
    test_acc = accuracy_score(y_test, y_test_preds)
    print(f'Precisión en validación ({name}): {val_acc:.2f}')
    print(f'Precisión en test ({name}): {test_acc:.2f}')

    model_accuracies.append({"Modelo": name, "Precisión Validación": round(val_acc, 4), "Precisión Test": round(test_acc, 4)})

    # Matrices de confusión lado a lado
    cm_val = confusion_matrix(y_val, y_val_preds)
    cm_test = confusion_matrix(y_test, y_test_preds)

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    for ax, cm, title in zip(
        axes,
        [cm_val, cm_test],
        [f'{name} - Matriz de Confusión (Validación)', f'{name} - Matriz de Confusión (Test)']
    ):
        im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        ax.set_title(title)
        tick_marks = np.arange(len(labels))
        ax.set_xticks(tick_marks)
        ax.set_yticks(tick_marks)
        ax.set_xticklabels([labels[0], labels[1]])
        ax.set_yticklabels([labels[0], labels[1]])
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            ax.text(j, i, cm[i, j], ha="center", color="white" if cm[i, j] > thresh else "black")
        ax.set_ylabel('Etiqueta real')
        ax.set_xlabel('Etiqueta predicha')

    fig.tight_layout()
    plt.colorbar(im, ax=axes.ravel().tolist())
    plt.show()

    # ROC y AUC (solo validación)
    fpr, tpr, _ = roc_curve(y_val, y_val_probs)
    roc_auc = auc(fpr, tpr)
    print(f"AUC ({name}): {roc_auc:.4f}")

    plt.figure(figsize=(6, 6))
    plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('Tasa de falsos positivos')
    plt.ylabel('Tasa de verdaderos positivos')
    plt.title(f'{name} - Curva ROC (Validación)')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

    # Classification Report (solo validación)
    print(f"\nInforme de Clasificación ({name} - Validación):")
    print(classification_report(y_val, y_val_preds, target_names=[labels[0], labels[1]]))

# %%
def train_model(model, preprocess_func, callbacks, epochs):
    """
    Entrena el modelo y devuelve el historial de entrenamiento
    """
    train_generator, validation_generator = create_generators(preprocess_func)

    history = model.fit(
        train_generator,
        epochs=epochs,
        validation_data=validation_generator,
        callbacks=callbacks
    )

    return history

# %% [markdown]
# ### 5.2 - Modelo VGG16

# %%
# Definición y compilación del modelo VGG16
with strategy.scope():
    vgg_model = Sequential(name="VGG16")
    vgg_model.add(VGG16(weights="imagenet", include_top=False, input_shape=IMG_SIZE + (3,)))
    vgg_model.layers[0].trainable = False
    vgg_model.add(layers.Flatten())
    vgg_model.add(layers.Dropout(0.5))
    vgg_model.add(layers.Dense(1, activation='sigmoid'))

    vgg_model.compile(
        loss='binary_crossentropy',
        optimizer=RMSprop(learning_rate=1e-4),
        metrics=['accuracy']
    )

# Entrenar y guardar historial
history_vgg = train_model(
    vgg_model,
    vgg_preprocess,
    callbacks=[early_stop, reduce_lr],
    epochs=EPOCHS
) m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m, m,
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Found 193 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 162s 23s/step - accuracy: 0.5778 - loss: 4.9065 - val_accuracy: 0.7000 - val_loss: 2.3752 - learning_rate: 1.0000e-04
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 152s 22s/step - accuracy: 0.5752 - loss: 4.4951 - val_accuracy: 0.8000 - val_loss: 2.1057 - learning_rate: 1.0000e-04
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 149s 21s/step - accuracy: 0.6305 - loss: 4.5735 - val_accuracy: 0.7200 - val_loss: 2.1724 - learning_rate: 1.0000e-04
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 158s 23s/step - accuracy: 0.6709 - loss: 4.0751 - val_accuracy: 0.8000 - val_loss: 1.9697 - learning_rate: 1.0000e-04
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 159s 23s/step - accuracy: 0.6540 - loss: 4.8985 - val_accuracy: 0.7600 - val_loss: 1.9787 - learning_rate: 1.0000e-04
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 154s 22s/step - accuracy: 0.6078 - loss: 4.3372 - val_accuracy: 0.7800 - val_loss: 1.8791 - learning_rate: 1.0000e-04
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 197s 25s/step - accuracy: 0.7723 - loss: 2.1014 - val_accuracy: 0.7800 - val_loss: 2.0111 - learning_rate: 1.0000e-04
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 152s 22s/step - accuracy: 0.7090 - loss: 2.9762 - val_accuracy: 0.7800 - val_loss: 1.8281 - learning_rate: 1.0000e-04
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 151s 22s/step - accuracy: 0.6524 - loss: 3.2393 - val_accuracy: 0.8000 - val_loss: 1.8358 - learning_rate: 1.0000e-04
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 150s 21s/step - accuracy: 0.7656 - loss: 1.9901 - val_accuracy: 0.7400 - val_loss: 2.2966 - learning_rate: 1.0000e-04
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 199s 21s/step - accuracy: 0.7127 - loss: 2.2872 - val_accuracy: 0.8000 - val_loss: 1.8050 - learning_rate: 1.0000e-04
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 148s 21s/step - accuracy: 0.6975 - loss: 3.3787 - val_accuracy: 0.8000 - val_loss: 1.5334 - learning_rate: 1.0000e-04
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 149s 21s/step - accuracy: 0.6972 - loss: 2.6119 - val_accuracy: 0.8400 - val_loss: 1.4883 - learning_rate: 1.0000e-04
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 149s 21s/step - accuracy: 0.6307 - loss: 3.7367 - val_accuracy: 0.8400 - val_loss: 1.3987 - learning_rate: 1.0000e-04
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 151s 22s/step - accuracy: 0.7520 - loss: 2.4621 - val_accuracy: 0.8400 - val_loss: 1.3371 - learning_rate: 1.0000e-04
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 150s 22s/step - accuracy: 0.7472 - loss: 2.3492 - val_accuracy: 0.8000 - val_loss: 1.5068 - learning_rate: 1.0000e-04
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 148s 21s/step - accuracy: 0.7962 - loss: 1.9292 - val_accuracy: 0.8400 - val_loss: 1.1841 - learning_rate: 1.0000e-04
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 148s 21s/step - accuracy: 0.8203 - loss: 1.5290 - val_accuracy: 0.8200 - val_loss: 1.2466 - learning_rate: 1.0000e-04
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 149s 21s/step - accuracy: 0.8433 - loss: 1.6796 - val_accuracy: 0.7800 - val_loss: 1.5950 - learning_rate: 1.0000e-04
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 147s 21s/step - accuracy: 0.8657 - loss: 1.0583 - val_accuracy: 0.9200 - val_loss: 0.4763 - learning_rate: 1.0000e-04
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 146s 21s/step - accuracy: 0.8405 - loss: 1.9869 - val_accuracy: 0.9200 - val_loss: 0.4458 - learning_rate: 1.0000e-04
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 146s 21s/step - accuracy: 0.8036 - loss: 1.6450 - val_accuracy: 0.9200 - val_loss: 0.4517 - learning_rate: 1.0000e-04
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 157s 23s/step - accuracy: 0.8060 - loss: 1.2416 - val_accuracy: 0.9000 - val_loss: 0.5480 - learning_rate: 1.0000e-04
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - accuracy: 0.8550 - loss: 1.1459
# Epoch 46: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 157s 23s/step - accuracy: 0.8524 - loss: 1.1690 - val_accuracy: 0.9000 - val_loss: 0.4996 - learning_rate: 1.0000e-04
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 203s 23s/step - accuracy: 0.9126 - loss: 0.7676 - val_accuracy: 0.9200 - val_loss: 0.5194 - learning_rate: 5.0000e-05
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 189s 21s/step - accuracy: 0.8596 - loss: 0.9842 - val_accuracy: 0.9200 - val_loss: 0.5171 - learning_rate: 5.0000e-05
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 146s 21s/step - accuracy: 0.9224 - loss: 0.9892 - val_accuracy: 0.9200 - val_loss: 0.5241 - learning_rate: 5.0000e-05
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 146s 21s/step - accuracy: 0.8402 - loss: 1.7235 - val_accuracy: 0.8800 - val_loss: 0.6278 - learning_rate: 5.0000e-05
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - accuracy: 0.8793 - loss: 0.9861
# Epoch 51: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 146s 21s/step - accuracy: 0.8802 - loss: 0.9982 - val_accuracy: 0.8800 - val_loss: 0.8093 - learning_rate: 5.0000e-05
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 41.

# %%
# Resultados de VGG16
plot_training_history(history_vgg, "VGG16")
evaluate_model(vgg_model, vgg_preprocess, "VGG16")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 57s 23s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# Precisión en validación (VGG16): 0.92
# Precisión en test (VGG16): 0.70
# AUC (VGG16): 0.9660
# Informe de Clasificación (VGG16 - Validación):
#               precision    recall  f1-score   support
#
#           NO       0.89      0.89      0.89        19
#          YES       0.94      0.94      0.94        31
#
#     accuracy                           0.92        50
#    macro avg       0.92      0.92      0.92        50
# weighted avg       0.92      0.92      0.92        50

# %% [markdown]
# ### 5.3 - Modelo ResNet50

# %%
# Definición y compilación del modelo ResNet50
with strategy.scope():
    resnet_model = Sequential(name="ResNet50")
    resnet_model.add(ResNet50(weights="imagenet", include_top=False, input_shape=IMG_SIZE + (3,)))
    resnet_model.layers[0].trainable = False
    resnet_model.add(layers.Flatten())
    resnet_model.add(layers.Dropout(0.5))
    resnet_model.add(layers.Dense(1, activation='sigmoid'))

    resnet_model.compile(
        loss='binary_crossentropy',
        optimizer=RMSprop(learning_rate=1e-4),
        metrics=['accuracy']
    )

# Entrenar y guardar historial
history_resnet = train_model(
    resnet_model,
    resnet_preprocess,
    callbacks=[early_stop, reduce_lr],
    epochs=EPOCHS
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Found 193 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 70s 9s/step - accuracy: 0.5645 - loss: 1.5247 - val_accuracy: 0.7600 - val_loss: 0.7440 - learning_rate: 1.0000e-04
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 47s 7s/step - accuracy: 0.6610 - loss: 0.7911 - val_accuracy: 0.8400 - val_loss: 0.6769 - learning_rate: 1.0000e-04
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/step - accuracy: 0.7348 - loss: 0.8446 - val_accuracy: 0.7200 - val_loss: 0.8150 - learning_rate: 1.0000e-04
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 48s 7s/step
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 16.

# %%
# Resultados de ResNet50
plot_training_history(history_resnet, "ResNet50")
evaluate_model(resnet_model, resnet_preprocess, "ResNet50")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Precisión en validación (ResNet50): 0.82
# Precisión en test (ResNet50): 0.70
# AUC (ResNet50): 0.9457
# Informe de Clasificación (ResNet50 - Validación):
#               precision    recall  f1-score   support
#
#           NO       0.78      0.74      0.76        19
#          YES       0.84      0.87      0.86        31
#
#     accuracy                           0.82        50
#    macro avg       0.81      0.80      0.81        50
# weighted avg       0.82      0.82      0.82        50

# %% [markdown]
# ### 5.4 - Modelo MobileNetV2

# %%
# Definición y compilación del modelo MobileNetV2
with strategy.scope():
    mobilenet_model = Sequential(name="MobileNetV2")
    mobilenet_model.add(MobileNetV2(weights="imagenet", include_top=False, input_shape=IMG_SIZE + (3,)))
    mobilenet_model.layers[0].trainable = False
    mobilenet_model.add(layers.Flatten())
    mobilenet_model.add(layers.Dropout(0.5))
    mobilenet_model.add(layers.Dense(1, activation='sigmoid'))

    mobilenet_model.compile(
        loss='binary_crossentropy',
        optimizer=RMSprop(learning_rate=1e-4),
        metrics=['accuracy']
    )

# Entrenar y guardar historial
history_mobilenet = train_model(
    mobilenet_model,
    mobilenet_preprocess,
    callbacks=[early_stop, reduce_lr],
    epochs=EPOCHS
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Found 193 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.5214 - loss: 1.1188 - val_accuracy: 0.6800 - val_loss: 0.5536 - learning_rate: 1.0000e-04
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7099 - loss: 0.5856 - val_accuracy: 0.7400 - val_loss: 0.4662 - learning_rate: 1.0000e-04
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7695 - loss: 0.5448 - val_accuracy: 0.8000 - val_loss: 0.4123 - learning_rate: 1.0000e-04
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.6767 - loss: 0.7962 - val_accuracy: 0.7400 - val_loss: 0.4424 - learning_rate: 1.0000e-04
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7021 - loss: 0.8661 - val_accuracy: 0.7200 - val_loss: 0.4752 - learning_rate: 1.0000e-04
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8372 - loss: 0.3939 - val_accuracy: 0.8000 - val_loss: 0.3677 - learning_rate: 1.0000e-04
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8950 - loss: 0.3178 - val_accuracy: 0.8000 - val_loss: 0.3875 - learning_rate: 1.0000e-04
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8590 - loss: 0.3608 - val_accuracy: 0.8400 - val_loss: 0.3491 - learning_rate: 1.0000e-04
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9017 - loss: 0.2577 - val_accuracy: 0.8400 - val_loss: 0.3292 - learning_rate: 1.0000e-04
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8683 - loss: 0.2738 - val_accuracy: 0.8400 - val_loss: 0.3357 - learning_rate: 1.0000e-04
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8853 - loss: 0.3297 - val_accuracy: 0.8400 - val_loss: 0.3500 - learning_rate: 1.0000e-04
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8393 - loss: 0.3638 - val_accuracy: 0.8400 - val_loss: 0.3451 - learning_rate: 1.0000e-04
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9089 - loss: 0.2284 - val_accuracy: 0.8400 - val_loss: 0.3411 - learning_rate: 1.0000e-04
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9247 - loss: 0.2412
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9218 - loss: 0.2456 - val_accuracy: 0.8600 - val_loss: 0.3399 - learning_rate: 1.0000e-04
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.9033 - loss: 0.2535 - val_accuracy: 0.8400 - val_loss: 0.3502 - learning_rate: 5.0000e-05
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8941 - loss: 0.2686 - val_accuracy: 0.8400 - val_loss: 0.3216 - learning_rate: 5.0000e-05
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9138 - loss: 0.2321 - val_accuracy: 0.8400 - val_loss: 0.3182 - learning_rate: 5.0000e-05
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8662 - loss: 0.3067 - val_accuracy: 0.8600 - val_loss: 0.3954 - learning_rate: 5.0000e-05
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8854 - loss: 0.3379 - val_accuracy: 0.8400 - val_loss: 0.3492 - learning_rate: 5.0000e-05
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9220 - loss: 0.1650 - val_accuracy: 0.8400 - val_loss: 0.3532 - learning_rate: 5.0000e-05
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.9317 - loss: 0.2539 - val_accuracy: 0.8800 - val_loss: 0.3372 - learning_rate: 5.0000e-05
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8789 - loss: 0.3362
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.8830 - loss: 0.3273 - val_accuracy: 0.8400 - val_loss: 0.3253 - learning_rate: 5.0000e-05
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.9102 - loss: 0.2306 - val_accuracy: 0.8600 - val_loss: 0.3204 - learning_rate: 2.5000e-05
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9197 - loss: 0.3499 - val_accuracy: 0.8600 - val_loss: 0.3163 - learning_rate: 2.5000e-05
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8835 - loss: 0.2439 - val_accuracy: 0.8400 - val_loss: 0.3187 - learning_rate: 2.5000e-05
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9038 - loss: 0.2523 - val_accuracy: 0.8400 - val_loss: 0.3175 - learning_rate: 2.5000e-05
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8907 - loss: 0.2982 - val_accuracy: 0.8400 - val_loss: 0.3241 - learning_rate: 2.5000e-05
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.8643 - loss: 0.2901 - val_accuracy: 0.8400 - val_loss: 0.3305 - learning_rate: 2.5000e-05
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8981 - loss: 0.2559
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9005 - loss: 0.2511 - val_accuracy: 0.8400 - val_loss: 0.3350 - learning_rate: 2.5000e-05
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9187 - loss: 0.2178 - val_accuracy: 0.8400 - val_loss: 0.3333 - learning_rate: 1.2500e-05
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9092 - loss: 0.2681 - val_accuracy: 0.8400 - val_loss: 0.3312 - learning_rate: 1.2500e-05
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8936 - loss: 0.3294 - val_accuracy: 0.8400 - val_loss: 0.3309 - learning_rate: 1.2500e-05
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9427 - loss: 0.1471 - val_accuracy: 0.8400 - val_loss: 0.3313 - learning_rate: 1.2500e-05
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9238 - loss: 0.1865
# Epoch 34: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9216 - loss: 0.1876 - val_accuracy: 0.8400 - val_loss: 0.3293 - learning_rate: 1.2500e-05
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.

# %%
# Resultados de MobileNetV2
plot_training_history(history_mobilenet, "MobileNetV2")
evaluate_model(mobilenet_model, mobilenet_preprocess, "MobileNetV2")
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a1ccde1e3e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 2s 3s/step
# WARNING:tensorflow:6 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a1ccde1e3e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# Precisión en validación (MobileNetV2): 0.84
# Precisión en test (MobileNetV2): 0.80
# AUC (MobileNetV2): 0.9542
# Informe de Clasificación (MobileNetV2 - Validación):
#               precision    recall  f1-score   support
#
#           NO       0.87      0.68      0.76        19
#          YES       0.83      0.94      0.88        31
#
#     accuracy                           0.84        50
#    macro avg       0.85      0.81      0.82        50
# weighted avg       0.84      0.84      0.84        50

# %% [markdown]
# ## 6 - Comparativa de los modelos

# %%
results_df = pd.DataFrame(model_accuracies)
results_df_sorted = results_df.sort_values(by="Precisión Validación", ascending=False)
display(results_df_sorted)
# Out:
#         Modelo  Precisión Validación  Precisión Test
# 0        VGG16                  0.92             0.7
# 2  MobileNetV2                  0.84             0.8
# 1     ResNet50                  0.82             0.7

# %%
# De los tres modelos evaluados, MobileNetV2 obtiene el mejor rendimiento en el conjunto de validación (90 %) y un buen AUC (~0.97), aunque en test su precisión baja al 70 %

# ResNet50 es el que mejor generaliza, con una precisión de ~80 % para test y validación

# VGG16 muestra signos de overfitting. Alcanza un 88 % en validación pero cae al 60 % en test
